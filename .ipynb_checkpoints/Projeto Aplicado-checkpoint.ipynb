# %% [markdown]
# ### Importando bibliotecas necessárias

# %%
import requests
import pandas as pd
import pprint
import json
from IPython.display import display
from concurrent.futures import ThreadPoolExecutor
#from gspread_pandas import Spread, Client

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
pd.set_option('display.max_colwidth',100)

# %%
#spread = Spread('Example Spreadsheet')

# %%
headers = {'accept': 'application/json'}
url = "https://dadosabertos.camara.leg.br/api/v2/deputados/204554/ano=2019&pagina=1&itens=100&ordem=ASC&ordenarPor=dataDocumento"
r = requests.get(url, headers=headers)

# %%
print(r.text)
# Out:
# {"status":404,"title":"Recurso não encontrado","detail":"A URL passada se refere a um recurso que não existe no sistema.","instance":" https://dadosabertos.camara.leg.br/api/v2/deputados/204554/ano","code":6}

# %%
if r.json()['dados']:
    print("tem dados")
# Out:
# tem dados

# %% [markdown]
# ### Processo de ETL

# %%
def listaDeputados(url):
    headers = {'accept': 'application/json'}
    r = requests.get(url, headers=headers)
    return r.json()['dados']

# %%
listaDeputados('https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome')
# Out:
# [{'id': 204554,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554',
#   'nome': 'ABÍLIO SANTANA',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg'},
#  {'id': 204521,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521',
#   'nome': 'ABOU ANNI',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg'},
#  {'id': 204379,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#   'nome': 'ACÁCIO FAVACHO',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'AP',
#   'idLegislatura': 56,
# ...

# %%
deputados = pd.DataFrame(listaDeputados('https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'))

# %%
deputados.head()
# Out:
#        id  idLegislatura             nome siglaPartido siglaUf  \
# 0  204554             56   ABÍLIO SANTANA           PL      BA
# 1  204521             56        ABOU ANNI          PSL      SP
# 2  204379             56   ACÁCIO FAVACHO         PROS      AP
# 3  204560             56     ADOLFO VIANA         PSDB      BA
# 4  204528             56  ADRIANA VENTURA         NOVO      SP
#
#                                                           uri  \
# 0  https://dadosabertos.camara.leg.br/api/v2/deputados/204554
# 1  https://dadosabertos.camara.leg.br/api/v2/deputados/204521
# 2  https://dadosabertos.camara.leg.br/api/v2/deputados/204379
# 3  https://dadosabertos.camara.leg.br/api/v2/deputados/204560
# 4  https://dadosabertos.camara.leg.br/api/v2/deputados/204528
#
#                                                  uriPartido  \
# 0  https://dadosabertos.camara.leg.br/api/v2/partidos/37906
# 1  https://dadosabertos.camara.leg.br/api/v2/partidos/36837
# ...

# %%
deputados.loc[deputados['nome'].str.contains('Tabata.*', regex=True, case=False)]['uri']

# %%
despesas = {}

# %%
# %%time
list_dataframes = []
for index, row in deputados.head(n=10).iterrows():
    pagina = 1
    while True:
        print(pagina)
        url = f"https://dadosabertos.camara.leg.br/api/v2/deputados/{row['id']}/despesas?ano=2019&pagina={pagina}&itens=100&ordem=ASC&ordenarPor=dataDocumento"
        print(url)
        headers = {'accept': 'application/json'}
        r = requests.get(url, headers=headers)
        if not r.json()['dados']:
            break
        desp_dep = pd.DataFrame(r.json()['dados'])
        #desp_dep[['dep_id','dep_nome','dep_partido','dep_uf']] = row[['id','nome','siglaPartido','siglaUf']]
        desp_dep['dep_id'] = row['id']
        desp_dep['dep_nome'] = row['nome']
        desp_dep['dep_partido'] = row['siglaPartido']
        desp_dep['dep_uf'] = row['siglaUf']
        #display(desp_dep.head())
        list_dataframes.append(desp_dep)
        #print(type(despesas[row['id']]))
        pagina = pagina + 1
despesas = pd.concat(list_dataframes)
# Out:
# 1
# https://dadosabertos.camara.leg.br/api/v2/deputados/204554/despesas?ano=2019&pagina=1&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 2
# https://dadosabertos.camara.leg.br/api/v2/deputados/204554/despesas?ano=2019&pagina=2&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 3
# https://dadosabertos.camara.leg.br/api/v2/deputados/204554/despesas?ano=2019&pagina=3&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 1
# https://dadosabertos.camara.leg.br/api/v2/deputados/204521/despesas?ano=2019&pagina=1&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 2
# https://dadosabertos.camara.leg.br/api/v2/deputados/204521/despesas?ano=2019&pagina=2&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 3
# https://dadosabertos.camara.leg.br/api/v2/deputados/204521/despesas?ano=2019&pagina=3&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 4
# https://dadosabertos.camara.leg.br/api/v2/deputados/204521/despesas?ano=2019&pagina=4&itens=100&ordem=ASC&ordenarPor=dataDocumento
# 1
# ...

# %%
# ETL usando thread
list_dataframes = []
'''
for index, row in deputados.head(n=10).iterrows():
    pagina = 1
    while True:
        print(pagina)
        url = f"https://dadosabertos.camara.leg.br/api/v2/deputados/{row['id']}/despesas?ano=2019&pagina={pagina}&itens=100&ordem=ASC&ordenarPor=dataDocumento"
        print(url)
        headers = {'accept': 'application/json'}
        r = requests.get(url, headers=headers)
        if not r.json()['dados']:
            break
        desp_dep = pd.DataFrame(r.json()['dados'])
        #desp_dep[['dep_id','dep_nome','dep_partido','dep_uf']] = row[['id','nome','siglaPartido','siglaUf']]
        desp_dep['dep_id'] = row['id']
        desp_dep['dep_nome'] = row['nome']
        desp_dep['dep_partido'] = row['siglaPartido']
        desp_dep['dep_uf'] = row['siglaUf']
        #display(desp_dep.head())
        list_dataframes.append(desp_dep)
        #print(type(despesas[row['id']]))
        pagina = pagina + 1
'''        
with ThreadPoolExecutor(4) as executor:
    results = executor.map(print, deputados['id'].tolist())
despesas = pd.concat(list_dataframes)
# Out:
# 204554
# 204521
# 204379
# 204560
# 20452812194874646
# 160508
# 136811
# 178835
#
# 160527
# 204495
# 204549
# 178836
# 160559
# 204413
# 204545
# 204501160511
# 178972
# 204571
# 204544
# 160545
# 204503
# 178833
# 204516
# 74057
# 178927
# 204353
# 204400
# 178937
# 178881
# 204356
# 178831
# 74471
# 204423
# 133439
# 178882
# 204515
#
# 73696
# 74212
# 160553
# 73433
# 141391
# 204414
# 160541
# 160600
# 15923774090
# 74459
# 160665
# 204509
# 160512
# 69871
# 178975
# 73701
# 109429
# 141335
# 204358
# 178948
# 207176
# 204374
# 204388
# 141513
# 204561
# 204397
# 160538
# 74052
# 204551
# 160589
# 204520
# 93083
# 204352
# 204572
# 178829
# 204487
# 204507
# 141401
# 204361
# 178962
# 178993
# 204460
# 74262
# 204426
# 141398
# 164360
# 204369
# 204499
# 204380
# 204370
# 178876
# 204488
# 141405
# 73441
# 204496
# 204504
# 205476
# 204490
# 141439
# 204476
# 204462
# 178928
# 204440
# 178939
# 74537
# 141408
# 204376
# 204378
# 204514
# 135054
# 204355
# 141411
# 74467
# ...

# %%
despesas.to_excel('despesas.xlsx')

# %%
despesas.groupby(by=['dep_id']).count()
# Out:
#         ano  cnpjCpfFornecedor  codDocumento  codLote  codTipoDocumento  \
# dep_id
# 204379   93                 93            93       93                93
# 204521  231                231           231      231               231
# 204554  151                151           151      151               151
#
#         dataDocumento  mes  nomeFornecedor  numDocumento  numRessarcimento  \
# dep_id
# 204379             89   93              93            93                93
# 204521            227  231             231           231               231
# 204554            147  151             151           151               151
#
#         parcela  tipoDespesa  tipoDocumento  urlDocumento  valorDocumento  \
# dep_id
# 204379       93           93             93            93              93
# 204521      231          231            231           231             231
# 204554      151          151            151           151             151
#
# ...

# %%
despesas.count()
# Out:
# ano                  2118
# cnpjCpfFornecedor    2118
# codDocumento         2118
# codLote              2118
# codTipoDocumento     2118
# dataDocumento        2075
# mes                  2118
# nomeFornecedor       2118
# numDocumento         2118
# numRessarcimento     2118
# parcela              2118
# tipoDespesa          2118
# tipoDocumento        2118
# urlDocumento         2118
# valorDocumento       2118
# valorGlosa           2118
# valorLiquido         2118
# dep_id               2118
# dep_nome             2118
# dep_partido          2118
# dep_uf               2118
# dtype: int64

# %% [markdown]
# ### Gráficos
